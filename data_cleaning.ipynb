# %%
import pandas as pd
import numpy as np

# define file path 
FILE_PATH = '/home/kip/Desktop/Sentiment-Analysis/HudumaNumber.txt'

# use pandas to read csv 
train = pd.read_csv(FILE_PATH)
train.head(3)
# Out:
#    Unnamed: 0                                       _api  \
# 0           0  <tweepy.api.API object at 0x7fe65d8f1780>
# 1           1  <tweepy.api.API object at 0x7fe65d8f1780>
# 2           2  <tweepy.api.API object at 0x7fe65d8f1780>
#
#                                                _json           created_at  \
# 0  {'created_at': 'Wed Jul 24 15:51:58 +0000 2019...  2019-07-24 15:51:58
# 1  {'created_at': 'Wed Jul 24 06:59:17 +0000 2019...  2019-07-24 06:59:17
# 2  {'created_at': 'Wed Jul 24 06:54:59 +0000 2019...  2019-07-24 06:54:59
#
#                     id               id_str  \
# 0  1154056637130399744  1154056637130399744
# 1  1153922585735966720  1153922585735966720
# 2  1153921501139230720  1153921501139230720
#
#                                                 text  truncated  \
# 0  And now they collected our data without any da...      False
# 1  RT @GreenShopEA1: what #hudumanumber can do #I...      False
# 2  what #hudumanumber can do #IdNamba can do bett...       True
#
#                                             entities  \
# 0  {'hashtags': [{'text': 'hudumanumber', 'indice...
# 1  {'hashtags': [{'text': 'hudumanumber', 'indice...
# 2  {'hashtags': [{'text': 'hudumanumber', 'indice...
#
#                                             metadata  ... favorite_count  \
# 0  {'iso_language_code': 'en', 'result_type': 're...  ...              0
# 1  {'iso_language_code': 'en', 'result_type': 're...  ...              0
# 2  {'iso_language_code': 'en', 'result_type': 're...  ...              0
#
#   favorited  retweeted  lang  \
# 0     False      False    en
# 1     False      False    en
# 2     False      False    en
#
#                                     retweeted_status  quoted_status_id  \
# 0                                                NaN               NaN
# 1  Status(_api=<tweepy.api.API object at 0x7fe65d...               NaN
# 2                                                NaN               NaN
#
#   quoted_status_id_str quoted_status possibly_sensitive  extended_entities
# 0                  NaN           NaN                NaN                NaN
# 1                  NaN           NaN                NaN                NaN
# 2                  NaN           NaN                NaN                NaN
#
# [3 rows x 35 columns]

# %%
# Number of Words
train['word_count'] = train['text'].apply(lambda x: len(str(x).split(" ")))
train[['text','word_count']].head()
# Out:
#                                                 text  word_count
# 0  And now they collected our data without any da...          14
# 1  RT @GreenShopEA1: what #hudumanumber can do #I...          15
# 2  what #hudumanumber can do #IdNamba can do bett...          13
# 3  RT @UzalendoNews_KE: It will now be mandatory ...          26
# 4  I believe @FredMatiangi has also committed an ...          19

# %%
# Number of characters
train['char_count'] = train['text'].str.len() ## this also includes spaces
train[['text','char_count']].head()
# Out:
#                                                 text  char_count
# 0  And now they collected our data without any da...          88
# 1  RT @GreenShopEA1: what #hudumanumber can do #I...         140
# 2  what #hudumanumber can do #IdNamba can do bett...         136
# 3  RT @UzalendoNews_KE: It will now be mandatory ...         140
# 4  I believe @FredMatiangi has also committed an ...         140

# %%
# Average Word Length
def avg_word(sentence):
  words = sentence.split()
  return (sum(len(word) for word in words)/len(words))

train['avg_word'] = train['text'].apply(lambda x: avg_word(x))
train[['text','avg_word']].head()
# Out:
#                                                 text  avg_word
# 0  And now they collected our data without any da...  5.357143
# 1  RT @GreenShopEA1: what #hudumanumber can do #I...  8.400000
# 2  what #hudumanumber can do #IdNamba can do bett...  9.538462
# 3  RT @UzalendoNews_KE: It will now be mandatory ...  4.423077
# 4  I believe @FredMatiangi has also committed an ...  6.421053

# %%
# Number of stopwords
from nltk.corpus import stopwords
stop = stopwords.words('english')

train['stopwords'] = train['text'].apply(lambda x: len([x for x in x.split() if x in stop]))
train[['text','stopwords']].head()
# Out:
#                                                 text  stopwords
# 0  And now they collected our data without any da...          5
# 1  RT @GreenShopEA1: what #hudumanumber can do #I...          5
# 2  what #hudumanumber can do #IdNamba can do bett...          5
# 3  RT @UzalendoNews_KE: It will now be mandatory ...         12
# 4  I believe @FredMatiangi has also committed an ...          5

# %%
# Number of special characters
train['hastags'] = train['text'].apply(lambda x: len([x for x in x.split() if x.startswith('#')]))
train[['text','hastags']].head()
# Out:
#                                                 text  hastags
# 0  And now they collected our data without any da...        1
# 1  RT @GreenShopEA1: what #hudumanumber can do #I...        7
# 2  what #hudumanumber can do #IdNamba can do bett...        6
# 3  RT @UzalendoNews_KE: It will now be mandatory ...        0
# 4  I believe @FredMatiangi has also committed an ...        1

# %%
#  Number of numerics
train['numerics'] = train['text'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
train[['text','numerics']].head()
# Out:
#                                                 text  numerics
# 0  And now they collected our data without any da...         0
# 1  RT @GreenShopEA1: what #hudumanumber can do #I...         0
# 2  what #hudumanumber can do #IdNamba can do bett...         0
# 3  RT @UzalendoNews_KE: It will now be mandatory ...         0
# 4  I believe @FredMatiangi has also committed an ...         0

# %%
# Number of Uppercase words
train['upper'] = train['text'].apply(lambda x: len([x for x in x.split() if x.isupper()]))
train[['text','upper']].head()
# Out:
#                                                 text  upper
# 0  And now they collected our data without any da...      0
# 1  RT @GreenShopEA1: what #hudumanumber can do #I...      1
# 2  what #hudumanumber can do #IdNamba can do bett...      0
# 3  RT @UzalendoNews_KE: It will now be mandatory ...      1
# 4  I believe @FredMatiangi has also committed an ...      1

# %%
# Lower case
train['text'] = train['text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
train['text'].head()
# Out:
# 0    and now they collected our data without any da...
# 1    rt @greenshopea1: what #hudumanumber can do #i...
# 2    what #hudumanumber can do #idnamba can do bett...
# 3    rt @uzalendonews_ke: it will now be mandatory ...
# 4    i believe @fredmatiangi has also committed an ...
# Name: text, dtype: object

# %%
# Removing Punctuation
train['text'] = train['text'].str.replace('[^\w\s]','')
train['text'].head()
# Out:
# 0    and now they collected our data without any da...
# 1    rt greenshopea1 what hudumanumber can do idnam...
# 2    what hudumanumber can do idnamba can do better...
# 3    rt uzalendonews_ke it will now be mandatory fo...
# 4    i believe fredmatiangi has also committed an o...
# Name: text, dtype: object

# %%
#  Removal of Stop Words
from nltk.corpus import stopwords
stop = stopwords.words('english')
train['text'] = train['text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
train['text'].head()
# Out:
# 0    collected data without data protection laws pl...
# 1    rt greenshopea1 hudumanumber idnamba better kt...
# 2    hudumanumber idnamba better ktnnewscentre hudu...
# 3    rt uzalendonews_ke mandatory kenyans huduma na...
# 4    believe fredmatiangi also committed offense en...
# Name: text, dtype: object

# %%
# Common word removal
freq = pd.Series(' '.join(train['text']).split()).value_counts()[:10]
freq
# remove these words as their presence will not of any use in classification of our text data.
freq = list(freq.index)
train['text'] = train['text'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
train['text'].head()
# Out:
# 0              collected without protection laws place
# 1    greenshopea1 idnamba better ktnnewscentre hudu...
# 2    idnamba better ktnnewscentre hudumabill2019 hu...
# 3    uzalendonews_ke mandatory kenyans huduma namba...
# 4    believe fredmatiangi committed offense engagin...
# Name: text, dtype: object

# %%
# Rare words removal
freq = pd.Series(' '.join(train['text']).split()).value_counts()[-10:]
freq
freq = list(freq.index)
train['text'] = train['text'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
train['text'].head()
# Out:
# 0              collected without protection laws place
# 1    greenshopea1 idnamba better ktnnewscentre hudu...
# 2    idnamba better ktnnewscentre hudumabill2019 hu...
# 3    uzalendonews_ke mandatory kenyans huduma namba...
# 4    believe fredmatiangi committed offense engagin...
# Name: text, dtype: object

# %%
# Spelling correction
from textblob import TextBlob
train['text'][:5].apply(lambda x: str(TextBlob(x).correct()))
# Out:
# 0              collected without protection laws place
# 1    greenshopea1 idnamba better ktnnewscentre hudu...
# 2    idnamba better ktnnewscentre hudumabill2019 hu...
# 3    uzalendonews_ke mandatory kenyans huduma name ...
# 4    believe fredmatiangi committed offense engagin...
# Name: text, dtype: object

# %%
# Stemming
from nltk.stem import PorterStemmer
st = PorterStemmer()
train['text'][:5].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
# Out:
# 0                    collect without protect law place
# 1    greenshopea1 idnamba better ktnnewscentr hudum...
# 2    idnamba better ktnnewscentr hudumabill2019 hud...
# 3    uzalendonews_k mandatori kenyan huduma namba g...
# 4    believ fredmatiangi commit offens engag projec...
# Name: text, dtype: object

# %%
train.head(3)
# Out:
#    Unnamed: 0                                       _api  \
# 0           0  <tweepy.api.API object at 0x7fe65d8f1780>
# 1           1  <tweepy.api.API object at 0x7fe65d8f1780>
# 2           2  <tweepy.api.API object at 0x7fe65d8f1780>
#
#                                                _json           created_at  \
# 0  {'created_at': 'Wed Jul 24 15:51:58 +0000 2019...  2019-07-24 15:51:58
# 1  {'created_at': 'Wed Jul 24 06:59:17 +0000 2019...  2019-07-24 06:59:17
# 2  {'created_at': 'Wed Jul 24 06:54:59 +0000 2019...  2019-07-24 06:54:59
#
#                     id               id_str  \
# 0  1154056637130399744  1154056637130399744
# 1  1153922585735966720  1153922585735966720
# 2  1153921501139230720  1153921501139230720
#
#                                                 text  truncated  \
# 0            collected without protection laws place      False
# 1  greenshopea1 idnamba better ktnnewscentre hudu...      False
# 2  idnamba better ktnnewscentre hudumabill2019 hu...       True
#
#                                             entities  \
# 0  {'hashtags': [{'text': 'hudumanumber', 'indice...
# 1  {'hashtags': [{'text': 'hudumanumber', 'indice...
# 2  {'hashtags': [{'text': 'hudumanumber', 'indice...
#
#                                             metadata  ... quoted_status  \
# 0  {'iso_language_code': 'en', 'result_type': 're...  ...           NaN
# 1  {'iso_language_code': 'en', 'result_type': 're...  ...           NaN
# 2  {'iso_language_code': 'en', 'result_type': 're...  ...           NaN
#
#   possibly_sensitive  extended_entities  word_count  char_count  avg_word  \
# 0                NaN                NaN          14          88  5.357143
# 1                NaN                NaN          15         140  8.400000
# 2                NaN                NaN          13         136  9.538462
#
#   stopwords hastags numerics  upper
# 0         5       1        0      0
# 1         5       7        0      1
# 2         5       6        0      0
#
# [3 rows x 42 columns]

# %%
list(train.columns)
# Out:
# ['Unnamed: 0',
#  '_api',
#  '_json',
#  'created_at',
#  'id',
#  'id_str',
#  'text',
#  'truncated',
#  'entities',
#  'metadata',
#  'source',
#  'source_url',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'in_reply_to_screen_name',
#  'author',
#  'user',
#  'geo',
#  'coordinates',
#  'place',
#  'contributors',
#  'is_quote_status',
#  'retweet_count',
#  'favorite_count',
#  'favorited',
#  'retweeted',
#  'lang',
#  'retweeted_status',
#  'quoted_status_id',
#  'quoted_status_id_str',
#  'quoted_status',
#  'possibly_sensitive',
#  'extended_entities',
#  'word_count',
#  'char_count',
#  'avg_word',
#  'stopwords',
#  'hastags',
#  'numerics',
#  'upper']

# %%
data = pd.DataFrame(train[['created_at','text','word_count','char_count','avg_word','stopwords','hastags','numerics','upper']])
data.head(3)
# Out:
#             created_at                                               text  \
# 0  2019-07-24 15:51:58            collected without protection laws place
# 1  2019-07-24 06:59:17  greenshopea1 idnamba better ktnnewscentre hudu...
# 2  2019-07-24 06:54:59  idnamba better ktnnewscentre hudumabill2019 hu...
#
#    word_count  char_count  avg_word  stopwords  hastags  numerics  upper
# 0          14          88  5.357143          5        1         0      0
# 1          15         140  8.400000          5        7         0      1
# 2          13         136  9.538462          5        6         0      0

# %%
# define file path (string) to save csv file to
FILE_PATH = '/home/kip/Desktop/Sentiment-Analysis/HudumaNumb.csv'

# use pandas to save dataframe to csv
data.to_csv(FILE_PATH)

# %%
# define file path 
FILE_PATH = '/home/kip/Desktop/Sentiment-Analysis/HudumaNumb.csv'

# use pandas to read csv 
train = pd.read_csv(FILE_PATH)
train.head(3)
# Out:
#    Unnamed: 0           created_at  \
# 0           0  2019-07-24 15:51:58
# 1           1  2019-07-24 06:59:17
# 2           2  2019-07-24 06:54:59
#
#                                                 text  word_count  char_count  \
# 0            collected without protection laws place          14          88
# 1  greenshopea1 idnamba better ktnnewscentre hudu...          15         140
# 2  idnamba better ktnnewscentre hudumabill2019 hu...          13         136
#
#    avg_word  stopwords  hastags  numerics  upper
# 0  5.357143          5        1         0      0
# 1  8.400000          5        7         0      1
# 2  9.538462          5        6         0      0
